# %%
pip install control --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy  --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from control import matlab as mt
import control as ct
import numpy as np
import pandas as pd
import warnings
import scipy
warnings.filterwarnings("ignore")

# %%
num=[3,-1];
den=[1,3,2];

# %%
tf=mt.tf(num,den)

# %%
tf
# Out:
# TransferFunction(
# array([ 3, -1]),
# array([1, 3, 2]),
# outputs=1, inputs=1)

# %%
mag,phase,omega=mt.bode(tf)

# %%
tf=mt.tf([1],[2,1])

# %%
tf
# Out:
# TransferFunction(
# array([1]),
# array([2, 1]),
# outputs=1, inputs=1)

# %%
mag,phase,phase=mt.bode(tf)

# %%
s=mt.tf('s')

# %%
num=3*(s+3)*(s+1.5)**3;
den=(s+5)*(s+7)**3

# %%
sys=num/den
sys
# Out:
# TransferFunction(
# array([ 3.   , 22.5  , 60.75 , 70.875, 30.375]),
# array([   1,   26,  252, 1078, 1715]),
# outputs=1, inputs=1)

# %%
mag,phase,omega=mt.bode(sys)
