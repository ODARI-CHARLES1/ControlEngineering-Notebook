# %%
pip install control
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from control import matlab as mt
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
num=[3,-1];
den=[1,3,2];

# %%
tf=mt.tf(num,den)

# %%
tf
# Out:
# TransferFunction(
# array([ 3, -1]),
# array([1, 3, 2]),
# outputs=1, inputs=1)

# %%
mag,phase,omega=mt.bode(tf)

# %%
tf=mt.tf([1],[2,1])

# %%
tf
# Out:
# TransferFunction(
# array([1]),
# array([2, 1]),
# outputs=1, inputs=1)

# %%
mag,phase,phase=mt.bode(tf)
