# %%
import sympy as sp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sympy.abc import m,x,y,t,s,v,M,theta,V,i,q,R,C,L

# %%
v=sp.Function('v')(t)
q=sp.Function('q')(t)
i=sp.Function('i')(t)

# %%
#Mass

x=sp.Function('x')(t)
F=Ma=M*sp.diff(v,t)
F
# Out:
# M*Derivative(v(t), t)

# %%
F=M*sp.diff(x,t,2)
F
# Out:
# M*Derivative(x(t), (t, 2))

# %%
theta
# Out:
# theta

# %%
v=R*i+L*sp.diff(i,t)+1/C*sp.integrate(i,t)
v
# Out:
# L*Derivative(i(t), t) + R*i(t) + Integral(i(t), t)/C

# %%
i=sp.diff(q,t)

# %%
v
# Out:
# L*Derivative(i(t), t) + R*i(t) + Integral(i(t), t)/C

# %%
v=v.subs(i,sp.diff(q,t))

# %%
v
# Out:
# L*Derivative(i(t), t) + R*i(t) + Integral(i(t), t)/C
